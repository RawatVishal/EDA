# %%
pip install dtale
# Out:
# Requirement already satisfied: dtale in c:\users\vishal\anaconda3\lib\site-packages (2.8.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.11.2)
# Requirement already satisfied: scikit-learn in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.24.2)
# Requirement already satisfied: requests in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (2.26.0)
# Requirement already satisfied: six in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (1.16.0)
# Requirement already satisfied: pandas in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (1.3.4)
# Requirement already satisfied: lz4 in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (4.0.2)
# Requirement already satisfied: openpyxl in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (3.0.9)
# Requirement already satisfied: certifi in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (2021.10.8)
# Requirement already satisfied: dash-colorscales in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.0.4)
# Requirement already satisfied: Flask in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (1.1.2)
# Requirement already satisfied: Flask-Compress in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (1.13)
# Requirement already satisfied: statsmodels in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.13.2)
# Requirement already satisfied: dash-bootstrap-components in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (1.2.1)
# Requirement already satisfied: itsdangerous in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: squarify in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.4.3)
# Requirement already satisfied: scipy in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (1.7.1)
# Requirement already satisfied: dash-daq in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.5.0)
#
# Requirement already satisfied: dash>=2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (2.6.2)
# Requirement already satisfied: numpy in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (1.20.3)
# Requirement already satisfied: xarray in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (2022.6.0)
# Requirement already satisfied: kaleido in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: strsimpy in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.2.1)
# Requirement already satisfied: networkx in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (2.6.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (5.10.0)
# Requirement already satisfied: flask-ngrok in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.0.25)
# Requirement already satisfied: missingno<=0.4.2 in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.4.2)
# Requirement already satisfied: cycler in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.10.0)
# Requirement already satisfied: matplotlib in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (3.4.3)
# Requirement already satisfied: xlrd in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (2.0.1)
# Requirement already satisfied: future>=0.14.0 in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (0.18.2)
# Requirement already satisfied: et-xmlfile in c:\users\vishal\anaconda3\lib\site-packages (from dtale) (1.1.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from dash>=2.0.0->dtale) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from dash>=2.0.0->dtale) (5.0.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\vishal\anaconda3\lib\site-packages (from Flask->dtale) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\vishal\anaconda3\lib\site-packages (from Flask->dtale) (8.0.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\vishal\anaconda3\lib\site-packages (from Flask->dtale) (2.0.2)
# Requirement already satisfied: colorama in c:\users\vishal\anaconda3\lib\site-packages (from click>=5.1->Flask->dtale) (0.4.4)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vishal\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask->dtale) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\vishal\anaconda3\lib\site-packages (from plotly>=5.0.0->dtale) (8.0.1)
# Requirement already satisfied: brotli in c:\users\vishal\anaconda3\lib\site-packages (from Flask-Compress->dtale) (1.0.9)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib->dtale) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib->dtale) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib->dtale) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib->dtale) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\vishal\anaconda3\lib\site-packages (from pandas->dtale) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vishal\anaconda3\lib\site-packages (from requests->dtale) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vishal\anaconda3\lib\site-packages (from requests->dtale) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from requests->dtale) (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\vishal\anaconda3\lib\site-packages (from scikit-learn->dtale) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from scikit-learn->dtale) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\vishal\anaconda3\lib\site-packages (from statsmodels->dtale) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\vishal\anaconda3\lib\site-packages (from statsmodels->dtale) (0.5.2)

# %%
import pandas as pd
df = pd.read_csv("Visadataset.csv")

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
import dtale
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-0JQT2IO:40000/dtale/iframe/2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
pip install pandas-profiling
# Out:
# Requirement already satisfied: pandas-profiling in c:\users\vishal\anaconda3\lib\site-packages (3.3.0)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (0.1.12)
# Requirement already satisfied: pydantic<1.10,>=1.8.1 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (1.9.2)
# Requirement already satisfied: missingno<0.6,>=0.4.2 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (0.4.2)
# Requirement already satisfied: seaborn<0.12,>=0.10.1 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (0.11.2)
# Requirement already satisfied: scipy<1.10,>=1.4.1 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (1.7.1)
# Requirement already satisfied: tangled-up-in-unicode==0.2.0 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (0.2.0)
# Requirement already satisfied: multimethod<1.9,>=1.4 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (1.8)
# Requirement already satisfied: matplotlib<3.6,>=3.2 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (3.4.3)
# Requirement already satisfied: visions[type_image_path]==0.7.5 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (0.7.5)
# Requirement already satisfied: pandas!=1.4.0,<1.5,>1.1 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (1.3.4)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (2.11.3)
# Requirement already satisfied: numpy<1.24,>=1.16.0 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (1.20.3)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (0.12.2)
# Requirement already satisfied: requests<2.29,>=2.24.0 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (2.26.0)
# Requirement already satisfied: statsmodels<0.14,>=0.13.2 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (0.13.2)
# Requirement already satisfied: joblib~=1.1.0 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (1.1.0)
# Requirement already satisfied: tqdm<4.65,>=4.48.2 in c:\users\vishal\anaconda3\lib\site-packages (from pandas-profiling) (4.62.3)
# Requirement already satisfied: networkx>=2.4 in c:\users\vishal\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (2.6.3)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\vishal\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (21.2.0)
# Requirement already satisfied: imagehash in c:\users\vishal\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (4.3.0)
# Requirement already satisfied: Pillow in c:\users\vishal\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.5->pandas-profiling) (8.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vishal\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->pandas-profiling) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib<3.6,>=3.2->pandas-profiling) (0.10.0)
# Requirement already satisfied: six in c:\users\vishal\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib<3.6,>=3.2->pandas-profiling) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\vishal\anaconda3\lib\site-packages (from pandas!=1.4.0,<1.5,>1.1->pandas-profiling) (2021.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\vishal\anaconda3\lib\site-packages (from pydantic<1.10,>=1.8.1->pandas-profiling) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vishal\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vishal\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vishal\anaconda3\lib\site-packages (from requests<2.29,>=2.24.0->pandas-profiling) (1.26.7)
# Requirement already satisfied: packaging>=21.3 in c:\users\vishal\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\vishal\anaconda3\lib\site-packages (from statsmodels<0.14,>=0.13.2->pandas-profiling) (0.5.2)
# Requirement already satisfied: colorama in c:\users\vishal\anaconda3\lib\site-packages (from tqdm<4.65,>=4.48.2->pandas-profiling) (0.4.4)
# Requirement already satisfied: PyWavelets in c:\users\vishal\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.5->pandas-profiling) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df1 = pd.read_csv("Visadataset.csv")

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(df1,explorative=True)
profile.to_file('output.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.1.4-py3-none-any.whl (15.1 MB)
# Collecting importlib-resources>=1.2.0
#   Downloading importlib_resources-5.9.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: tqdm>=4.43.0 in c:\users\vishal\anaconda3\lib\site-packages (from sweetviz) (4.62.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\vishal\anaconda3\lib\site-packages (from sweetviz) (1.20.3)
# Requirement already satisfied: matplotlib>=3.1.3 in c:\users\vishal\anaconda3\lib\site-packages (from sweetviz) (3.4.3)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\vishal\anaconda3\lib\site-packages (from sweetviz) (2.11.3)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in c:\users\vishal\anaconda3\lib\site-packages (from sweetviz) (1.3.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\vishal\anaconda3\lib\site-packages (from sweetviz) (1.7.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\vishal\anaconda3\lib\site-packages (from importlib-resources>=1.2.0->sweetviz) (3.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vishal\anaconda3\lib\site-packages (from jinja2>=2.11.1->sweetviz) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.4)
# Requirement already satisfied: six in c:\users\vishal\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\vishal\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2021.3)
# Requirement already satisfied: colorama in c:\users\vishal\anaconda3\lib\site-packages (from tqdm>=4.43.0->sweetviz) (0.4.4)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-5.9.0 sweetviz-2.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv
report = sv.analyze(df1)
report.show_html('sweet_report.html')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
pip install autoviz
# Out:
# Collecting autoviz
#   Downloading autoviz-0.1.55-py3-none-any.whl (64 kB)
# Requirement already satisfied: fsspec>=0.8.3 in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (2021.10.1)
# Collecting typing-extensions>=4.1.1
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: jupyter in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (1.0.0)
# Requirement already satisfied: numpy in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (1.20.3)
# Collecting bokeh>=2.4.2
#   Downloading bokeh-2.4.3-py3-none-any.whl (18.5 MB)
# Collecting panel~=0.12.6
#   Downloading panel-0.12.7-py2.py3-none-any.whl (12.9 MB)
# Requirement already satisfied: ipython in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (7.29.0)
# Collecting pyamg
#   Downloading pyamg-4.2.3-cp39-cp39-win_amd64.whl (1.4 MB)
# Requirement already satisfied: matplotlib>=3.3.3 in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (3.4.3)
# Collecting emoji
#   Downloading emoji-2.1.0.tar.gz (216 kB)
# Requirement already satisfied: xlrd in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (2.0.1)
# Collecting wordcloud
#   Using cached wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
# Requirement already satisfied: seaborn>=0.11.1 in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (0.11.2)
# Collecting xgboost>=0.82
#   Downloading xgboost-1.6.2-py3-none-win_amd64.whl (125.4 MB)
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
# Requirement already satisfied: scikit-learn in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (0.24.2)
# Requirement already satisfied: statsmodels in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (0.13.2)
# Requirement already satisfied: nltk in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (3.6.5)
# Requirement already satisfied: pandas in c:\users\vishal\anaconda3\lib\site-packages (from autoviz) (1.3.4)
# Collecting hvplot>=0.7.3
#   Downloading hvplot-0.8.1-py2.py3-none-any.whl (3.2 MB)
# Collecting holoviews>=1.14.6
#   Downloading holoviews-1.15.0-py2.py3-none-any.whl (4.3 MB)
# Requirement already satisfied: packaging>=16.8 in c:\users\vishal\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (21.3)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\vishal\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (8.4.0)
# Requirement already satisfied: tornado>=5.1 in c:\users\vishal\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (6.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\vishal\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\vishal\anaconda3\lib\site-packages (from bokeh>=2.4.2->autoviz) (2.11.3)
# Collecting colorcet
#   Downloading colorcet-3.0.0-py2.py3-none-any.whl (1.6 MB)
# Collecting param<2.0,>=1.9.3
#   Downloading param-1.12.2-py2.py3-none-any.whl (86 kB)
# Collecting holoviews>=1.14.6
#   Downloading holoviews-1.14.9-py2.py3-none-any.whl (4.3 MB)
# Collecting pyviz-comms>=0.7.4
#   Downloading pyviz_comms-2.2.1-py2.py3-none-any.whl (42 kB)
# Collecting pyct>=0.4.4
#   Downloading pyct-0.4.8-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\vishal\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh>=2.4.2->autoviz) (2.0.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (1.3.1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (3.0.4)
#
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vishal\anaconda3\lib\site-packages (from matplotlib>=3.3.3->autoviz) (2.8.2)
# Requirement already satisfied: six in c:\users\vishal\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib>=3.3.3->autoviz) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\vishal\anaconda3\lib\site-packages (from pandas->autoviz) (2021.3)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\vishal\anaconda3\lib\site-packages (from panel~=0.12.6->autoviz) (4.62.3)
# Requirement already satisfied: setuptools<61,>=42 in c:\users\vishal\anaconda3\lib\site-packages (from panel~=0.12.6->autoviz) (58.0.4)
# Requirement already satisfied: requests in c:\users\vishal\anaconda3\lib\site-packages (from panel~=0.12.6->autoviz) (2.26.0)
# Requirement already satisfied: bleach in c:\users\vishal\anaconda3\lib\site-packages (from panel~=0.12.6->autoviz) (4.0.0)
# Collecting markdown
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
# Requirement already satisfied: scipy>=1.0 in c:\users\vishal\anaconda3\lib\site-packages (from seaborn>=0.11.1->autoviz) (1.7.1)
# Requirement already satisfied: colorama in c:\users\vishal\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel~=0.12.6->autoviz) (0.4.4)
# Requirement already satisfied: webencodings in c:\users\vishal\anaconda3\lib\site-packages (from bleach->panel~=0.12.6->autoviz) (0.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from ipython->autoviz) (3.0.20)
# Requirement already satisfied: pygments in c:\users\vishal\anaconda3\lib\site-packages (from ipython->autoviz) (2.10.0)
# Requirement already satisfied: matplotlib-inline in c:\users\vishal\anaconda3\lib\site-packages (from ipython->autoviz) (0.1.2)
# Requirement already satisfied: backcall in c:\users\vishal\anaconda3\lib\site-packages (from ipython->autoviz) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\vishal\anaconda3\lib\site-packages (from ipython->autoviz) (5.1.0)
# Requirement already satisfied: decorator in c:\users\vishal\anaconda3\lib\site-packages (from ipython->autoviz) (5.1.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\vishal\anaconda3\lib\site-packages (from ipython->autoviz) (0.18.0)
# Requirement already satisfied: pickleshare in c:\users\vishal\anaconda3\lib\site-packages (from ipython->autoviz) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\vishal\anaconda3\lib\site-packages (from jedi>=0.16->ipython->autoviz) (0.8.2)
# Requirement already satisfied: wcwidth in c:\users\vishal\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviz) (0.2.5)
# Requirement already satisfied: qtconsole in c:\users\vishal\anaconda3\lib\site-packages (from jupyter->autoviz) (5.1.1)
# Requirement already satisfied: notebook in c:\users\vishal\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.5)
# Requirement already satisfied: jupyter-console in c:\users\vishal\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.0)
# Requirement already satisfied: nbconvert in c:\users\vishal\anaconda3\lib\site-packages (from jupyter->autoviz) (6.1.0)
# Requirement already satisfied: ipywidgets in c:\users\vishal\anaconda3\lib\site-packages (from jupyter->autoviz) (7.6.5)
# Requirement already satisfied: ipykernel in c:\users\vishal\anaconda3\lib\site-packages (from jupyter->autoviz) (6.4.1)
# Requirement already satisfied: ipython-genutils in c:\users\vishal\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (0.2.0)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\vishal\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (6.1.12)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from ipykernel->jupyter->autoviz) (1.4.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\vishal\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (4.8.1)
# Requirement already satisfied: pyzmq>=13 in c:\users\vishal\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->autoviz) (22.2.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\vishal\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter->autoviz) (228)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\vishal\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\vishal\anaconda3\lib\site-packages (from ipywidgets->jupyter->autoviz) (5.1.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\vishal\anaconda3\lib\site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\vishal\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\vishal\anaconda3\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviz) (21.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\vishal\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (20.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\vishal\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (0.9.4)
# Requirement already satisfied: prometheus-client in c:\users\vishal\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (0.11.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in c:\users\vishal\anaconda3\lib\site-packages (from notebook->jupyter->autoviz) (1.8.0)
# Requirement already satisfied: pywinpty>=0.5 in c:\users\vishal\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->autoviz) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->autoviz) (1.14.6)
# Requirement already satisfied: pycparser in c:\users\vishal\anaconda3\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->autoviz) (2.20)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\vishal\anaconda3\lib\site-packages (from markdown->panel~=0.12.6->autoviz) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\vishal\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown->panel~=0.12.6->autoviz) (3.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\vishal\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.8.4)
# Requirement already satisfied: testpath in c:\users\vishal\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.5.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\vishal\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\vishal\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\vishal\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.5.3)
# Requirement already satisfied: defusedxml in c:\users\vishal\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\vishal\anaconda3\lib\site-packages (from nbconvert->jupyter->autoviz) (0.3)
# Requirement already satisfied: async-generator in c:\users\vishal\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviz) (1.10)
# Requirement already satisfied: nest-asyncio in c:\users\vishal\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviz) (1.5.1)
# Requirement already satisfied: click in c:\users\vishal\anaconda3\lib\site-packages (from nltk->autoviz) (8.0.3)
# Requirement already satisfied: joblib in c:\users\vishal\anaconda3\lib\site-packages (from nltk->autoviz) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\vishal\anaconda3\lib\site-packages (from nltk->autoviz) (2021.8.3)
# Requirement already satisfied: qtpy in c:\users\vishal\anaconda3\lib\site-packages (from qtconsole->jupyter->autoviz) (1.10.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vishal\anaconda3\lib\site-packages (from requests->panel~=0.12.6->autoviz) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vishal\anaconda3\lib\site-packages (from requests->panel~=0.12.6->autoviz) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vishal\anaconda3\lib\site-packages (from requests->panel~=0.12.6->autoviz) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from requests->panel~=0.12.6->autoviz) (2.0.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\vishal\anaconda3\lib\site-packages (from scikit-learn->autoviz) (2.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\vishal\anaconda3\lib\site-packages (from statsmodels->autoviz) (0.5.2)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=b8c082d0faa05b1de38541d01f1883806fbf4d937dd1b2e5baa1f0569cb27e1b
#   Stored in directory: c:\users\vishal\appdata\local\pip\cache\wheels\b0\4a\c8\9c580a0ea94dea641b8023456a1b178a7e4509d992224ed4aa
# Successfully built emoji
# Installing collected packages: typing-extensions, param, pyviz-comms, pyct, markdown, bokeh, panel, colorcet, holoviews, xgboost, wordcloud, textblob, pyamg, hvplot, emoji, autoviz
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: bokeh
#     Found existing installation: bokeh 2.4.1
#     Uninstalling bokeh-2.4.1:
#       Successfully uninstalled bokeh-2.4.1
# Successfully installed autoviz-0.1.55 bokeh-2.4.3 colorcet-3.0.0 emoji-2.1.0 holoviews-1.14.9 hvplot-0.8.1 markdown-3.4.1 panel-0.12.7 param-1.12.2 pyamg-4.2.3 pyct-0.4.8 pyviz-comms-2.2.1 textblob-0.17.1 typing-extensions-4.3.0 wordcloud-1.8.2.2 xgboost-1.6.2

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
sep = ','
dft = AV.AutoViz(filename="",
                 sep=sep,
                 depVar='left',
                 dfte=df1, header=0, verbose=1, 
                 lowess=True, chart_format='jpg',
                 max_rows_analyzed=26000, max_cols_analyzed=13)
# Out:
# Shape of your Data Set loaded: (25480, 12)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
# <style type="text/css">
# #T_31db2_row0_col0, #T_31db2_row0_col4, #T_31db2_row1_col0, #T_31db2_row1_col4, #T_31db2_row8_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# #T_31db2_row0_col1, #T_31db2_row0_col6, #T_31db2_row1_col1, #T_31db2_row1_col6, #T_31db2_row2_col1, #T_31db2_row2_col6, #T_31db2_row3_col1, #T_31db2_row3_col6, #T_31db2_row4_col1, #T_31db2_row4_col6, #T_31db2_row5_col1, #T_31db2_row5_col6, #T_31db2_row6_col1, #T_31db2_row6_col6, #T_31db2_row7_col1, #T_31db2_row7_col6, #T_31db2_row8_col1, #T_31db2_row8_col6, #T_31db2_row9_col1, #T_31db2_row9_col6, #T_31db2_row10_col1, #T_31db2_row10_col6, #T_31db2_row11_col1, #T_31db2_row11_col6 {
#   font-family: Segoe UI;
# }
# #T_31db2_row0_col2, #T_31db2_row0_col3, #T_31db2_row0_col5, #T_31db2_row1_col2, #T_31db2_row1_col3, #T_31db2_row1_col5, #T_31db2_row2_col2, #T_31db2_row2_col3, #T_31db2_row2_col5, #T_31db2_row3_col2, #T_31db2_row3_col3, #T_31db2_row3_col5, #T_31db2_row4_col0, #T_31db2_row4_col2, #T_31db2_row4_col3, #T_31db2_row4_col4, #T_31db2_row5_col0, #T_31db2_row5_col2, #T_31db2_row5_col3, #T_31db2_row5_col4, #T_31db2_row6_col0, #T_31db2_row6_col2, #T_31db2_row6_col3, #T_31db2_row6_col4, #T_31db2_row7_col0, #T_31db2_row7_col2, #T_31db2_row7_col3, #T_31db2_row7_col4, #T_31db2_row8_col0, #T_31db2_row8_col2, #T_31db2_row8_col3, #T_31db2_row8_col4, #T_31db2_row9_col0, #T_31db2_row9_col2, #T_31db2_row9_col3, #T_31db2_row9_col4, #T_31db2_row10_col0, #T_31db2_row10_col2, #T_31db2_row10_col3, #T_31db2_row10_col4, #T_31db2_row11_col0, #T_31db2_row11_col2, #T_31db2_row11_col3, #T_31db2_row11_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row2_col0, #T_31db2_row2_col4 {
#   background-color: #fcb296;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row3_col0, #T_31db2_row3_col4 {
#   background-color: #fff4ef;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row4_col5 {
#   background-color: #fff2ec;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row5_col5 {
#   background-color: #fff0e8;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row6_col5 {
#   background-color: #fdc9b3;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row7_col5 {
#   background-color: #fff4ee;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row9_col5 {
#   background-color: #fcb398;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row10_col5 {
#   background-color: #fcbba1;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_31db2_row11_col5 {
#   background-color: #be151a;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_31db2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Nuniques</th>
#       <th class="col_heading level0 col1" >dtype</th>
#       <th class="col_heading level0 col2" >Nulls</th>
#       <th class="col_heading level0 col3" >Nullpercent</th>
#       <th class="col_heading level0 col4" >NuniquePercent</th>
#       <th class="col_heading level0 col5" >Value counts Min</th>
#       <th class="col_heading level0 col6" >Data cleaning improvement suggestions</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_31db2_level0_row0" class="row_heading level0 row0" >case_id</th>
#       <td id="T_31db2_row0_col0" class="data row0 col0" >25480</td>
#       <td id="T_31db2_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_31db2_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_31db2_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_31db2_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_31db2_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_31db2_row0_col6" class="data row0 col6" >combine rare categories, possible ID column: drop</td>
#     </tr>
#     <tr>
#       <th id="T_31db2_level0_row1" class="row_heading level0 row1" >prevailing_wage</th>
#       <td id="T_31db2_row1_col0" class="data row1 col0" >25454</td>
#       <td id="T_31db2_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_31db2_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_31db2_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_31db2_row1_col4" class="data row1 col4" >99.897959</td>
#       <td id="T_31db2_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_31db2_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_31db2_level0_row2" class="row_heading level0 row2" >no_of_employees</th>
#       <td id="T_31db2_row2_col0" class="data row2 col0" >7105</td>
#       <td id="T_31db2_row2_col1" class="data row2 col1" >int64</td>
#       <td id="T_31db2_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_31db2_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_31db2_row2_col4" class="data row2 col4" >27.884615</td>
#       <td id="T_31db2_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_31db2_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_31db2_level0_row3" class="row_heading level0 row3" >yr_of_estab</th>
#       <td id="T_31db2_row3_col0" class="data row3 col0" >199</td>
#       <td id="T_31db2_row3_col1" class="data row3 col1" >int64</td>
#       <td id="T_31db2_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_31db2_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_31db2_row3_col4" class="data row3 col4" >0.781005</td>
#       <td id="T_31db2_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_31db2_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_31db2_level0_row4" class="row_heading level0 row4" >continent</th>
#       <td id="T_31db2_row4_col0" class="data row4 col0" >6</td>
#       <td id="T_31db2_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_31db2_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_31db2_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_31db2_row4_col4" class="data row4 col4" >0.023548</td>
#       <td id="T_31db2_row4_col5" class="data row4 col5" >192</td>
#       <td id="T_31db2_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_31db2_level0_row5" class="row_heading level0 row5" >region_of_employment</th>
#       <td id="T_31db2_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_31db2_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_31db2_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_31db2_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_31db2_row5_col4" class="data row5 col4" >0.019623</td>
#       <td id="T_31db2_row5_col5" class="data row5 col5" >375</td>
#       <td id="T_31db2_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_31db2_level0_row6" class="row_heading level0 row6" >education_of_employee</th>
#       <td id="T_31db2_row6_col0" class="data row6 col0" >4</td>
#       <td id="T_31db2_row6_col1" class="data row6 col1" >object</td>
#       <td id="T_31db2_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_31db2_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_31db2_row6_col4" class="data row6 col4" >0.015699</td>
#       <td id="T_31db2_row6_col5" class="data row6 col5" >2192</td>
#       <td id="T_31db2_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_31db2_level0_row7" class="row_heading level0 row7" >unit_of_wage</th>
#       <td id="T_31db2_row7_col0" class="data row7 col0" >4</td>
#       <td id="T_31db2_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_31db2_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_31db2_row7_col3" class="data row7 col3" >0.000000</td>
#       <td id="T_31db2_row7_col4" class="data row7 col4" >0.015699</td>
#       <td id="T_31db2_row7_col5" class="data row7 col5" >89</td>
#       <td id="T_31db2_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_31db2_level0_row8" class="row_heading level0 row8" >has_job_experience</th>
#       <td id="T_31db2_row8_col0" class="data row8 col0" >2</td>
#       <td id="T_31db2_row8_col1" class="data
#     12 Predictors classified...
#         1 variables removed since they were ID or low-information variables
#         List of variables removed: ['case_id']
# Could not find given target var in data set. Please check input
# Not able to read or load file. Please check your inputs and try again...
